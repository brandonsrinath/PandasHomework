# %% [markdown]
# # Whale Return Data

# %%
#import

import pandas as pd
import seaborn as sns
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
#read the CSV files into DataFrames and perform any necessary data cleaning steps

whale_returns_csv = Path("Instructions/Starter_Code/Resources/whale_returns.csv")
whale_returns_data = pd.read_csv("Instructions/Starter_Code/Resources/whale_returns.csv",index_col="Date", infer_datetime_format=True, parse_dates=True).sort_index()


# shape of dataframe

whale_returns_data.shape
# Out:
# (1060, 4)

# %%
#Import Whale Portfolio
whale_returns_data.head()
whale_returns_data.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
#display null
whale_returns_data.isnull().mean()*100
# Out:
# SOROS FUND MANAGEMENT LLC      0.09434
# PAULSON & CO.INC.              0.09434
# TIGER GLOBAL MANAGEMENT LLC    0.09434
# BERKSHIRE HATHAWAY INC         0.09434
# dtype: float64

# %%
#Count the number of Null
whale_returns_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns_data.describe(include='all')
# Out:
#        SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# count                1059.000000         1059.000000
# mean                    0.000179           -0.000203
# std                     0.007842            0.006977
# min                    -0.032711           -0.032099
# 25%                    -0.003594           -0.003961
# 50%                     0.000467            0.000000
# 75%                     0.004292            0.003567
# max                     0.042977            0.029338
#
#        TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# count                  1059.000000             1059.000000
# mean                     -0.000081                0.000501
# std                       0.010824                0.012831
# min                      -0.139820               -0.066505
# 25%                      -0.004746               -0.005515
# 50%                       0.000232                0.000617
# 75%                       0.005176                0.007516
# ...

# %%
#display data nulls

whale_returns_data.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
#display data
whale_returns_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
#Count nulls in dataframe
whale_returns_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns_data = whale_returns_data.dropna()

# %%
#select whale_returns_data.iloc[0]first row 
whale_returns_data.iloc[0]
# Out:
# SOROS FUND MANAGEMENT LLC     -0.001266
# PAULSON & CO.INC.             -0.004981
# TIGER GLOBAL MANAGEMENT LLC   -0.000496
# BERKSHIRE HATHAWAY INC        -0.006569
# Name: 2015-03-03 00:00:00, dtype: float64

# %%
#Verify nulls have been dropped
whale_returns_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# # Algorithmic Daily Returns

# %%
#Create Path to algo_returns
algo_returns_csv = Path("Instructions/Starter_Code/Resources/algo_returns.csv")

#Read in csv for algo_returns
algo_returns_csv = pd.read_csv("Instructions/Starter_Code/Resources/algo_returns.csv",index_col="Date", infer_datetime_format=True, parse_dates=True).sort_index()

# %%
# Display data
algo_returns_csv.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
#Display nulls in data
algo_returns_csv.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#drop nulls usiing .dropna()
algo_returns_csv = algo_returns_csv.dropna()

# %%
#Verify nulls have been dropped
algo_returns_csv.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# # S&P 500 Returns

# %%
# Create Path to S&P Returns

sp500_history_csv_path = Path("Instructions/Starter_Code/Resources/sp500_history.csv")

#Read In S&P Returns
sp500_history_csv= pd.read_csv(sp500_history_csv_path,index_col="Date", infer_datetime_format=True, parse_dates=True).sort_index()

# %%
#Display data

sp500_history_csv.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
#Display number of rows
sp500_history_csv.shape
# Out:
# (1649, 1)

# %%
sp500_history_csv.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history_csv["Close"]
# Out:
# Date
# 2012-10-01    $1444.49
# 2012-10-02    $1445.75
# 2012-10-03    $1450.99
# 2012-10-04    $1461.40
# 2012-10-05    $1460.93
#                 ...
# 2019-04-16    $2907.06
# 2019-04-17    $2900.45
# 2019-04-18    $2905.03
# 2019-04-22    $2907.97
# 2019-04-23    $2933.68
# Name: Close, Length: 1649, dtype: object

# %%
sp500_history_csv["Close"] = sp500_history_csv["Close"].str.replace("$","")

# %%
sp500_history_csv["Close"]
# Out:
# Date
# 2012-10-01    1444.49
# 2012-10-02    1445.75
# 2012-10-03    1450.99
# 2012-10-04    1461.40
# 2012-10-05    1460.93
#                ...
# 2019-04-16    2907.06
# 2019-04-17    2900.45
# 2019-04-18    2905.03
# 2019-04-22    2907.97
# 2019-04-23    2933.68
# Name: Close, Length: 1649, dtype: object

# %%
sp500_history_csv["Close"]=sp500_history_csv["Close"].astype("float")

# %%
sp500_history_csv.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_percent_change = sp500_history_csv.pct_change()
sp500_percent_change
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
print(sp500_percent_change)
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
sp500_percent_change.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
sp500_percent_change.dropna(inplace=True)
print(sp500_percent_change)
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
sp500_percent_change.columns = ["S&P 500"]
print(sp500_percent_change)
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# # Combine Whale, Algorithmic, and S&P 500 Returns

# %%
combined_dataframe = pd.concat([whale_returns_data, algo_returns_csv, sp500_percent_change], axis=1, join = "inner")

# %%
combined_dataframe
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# # Portfolio Analysis

# %%
# Plot daily returns
combined_dataframe.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Plot cumulative returns
#cumulative_returns 
cumulative_returns = (1 + combined_dataframe).cumprod() - 1
cumulative_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
# ...                               ...                 ...
# 2019-04-16                   0.160965           -0.213189
# 2019-04-17                   0.157602           -0.218277
# 2019-04-18                   0.159278           -0.217322
# 2019-04-22                   0.156280           -0.223061
# 2019-04-23                   0.164568           -0.220354
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# ...

# %%
((combined_dataframe + 1).cumprod() - 1).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Risk

# %%
# Determine the risk of each portfolio:
# Create a box plot for each portfolio. 
# Calculate the standard deviation for all portfolios
# Determine which portfolios are riskier than the S&P 500
# Calculate the Annualized Standard Deviation

# Box plot to visually show risk for Whale Return

whale_returns_data.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#Box Plot algo
algo_returns_csv.plot.box()
# Out:
# <AxesSubplot:>

# %%
sp500_history_csv.plot.box()
# Out:
# <AxesSubplot:>

# %%
#Calculate Standard Deviation
sp500_history_csv.mean()
# Out:
# Close    2154.27946
# dtype: float64

# %%
algo_returns_csv.mean()
# Out:
# Algo 1    0.000654
# Algo 2    0.000341
# dtype: float64

# %%
whale_returns_data.mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.000179
# PAULSON & CO.INC.             -0.000203
# TIGER GLOBAL MANAGEMENT LLC   -0.000081
# BERKSHIRE HATHAWAY INC         0.000501
# dtype: float64

# %%
combined_dataframe.mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.000177
# PAULSON & CO.INC.             -0.000214
# TIGER GLOBAL MANAGEMENT LLC   -0.000083
# BERKSHIRE HATHAWAY INC         0.000506
# Algo 1                         0.000662
# Algo 2                         0.000263
# S&P 500                        0.000349
# dtype: float64

# %%
# sp 500 standard deviation std 
sp500_std = sp500_history_csv.std()
sp500_std
# Out:
# Close    402.122004
# dtype: float64

# %%
# whale_returns std 
whale_returns_std = whale_returns_data.std()
whale_returns_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
algo_returns_std = algo_returns_csv.std()
algo_returns_std
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
combined_dataframe_std = combined_dataframe.std()
combined_dataframe_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
combined_dataframe.describe()
# Out:
#        SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# count                1043.000000         1043.000000
# mean                    0.000177           -0.000214
# std                     0.007895            0.007023
# min                    -0.032711           -0.032099
# 25%                    -0.003638           -0.004042
# 50%                     0.000518            0.000000
# 75%                     0.004328            0.003626
# max                     0.042977            0.029338
#
#        TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC       Algo 1  \
# count                  1043.000000             1043.000000  1043.000000
# mean                     -0.000083                0.000506     0.000662
# std                       0.010894                0.012919     0.007620
# min                      -0.139820               -0.066505    -0.030951
# 25%                      -0.004790               -0.005634    -0.003252
# ...

# %%
type(combined_dataframe.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
combined_dataframe.describe().loc["25%", "TIGER GLOBAL MANAGEMENT LLC"]
# Out:
# -0.004789529145904525

# %%
sp500_std = combined_dataframe["S&P 500"].std()

# %%
sp500_std
# Out:
# 0.008553731597758204

# %%
combined_dataframe_std > sp500_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
np.sqrt(252)*combined_dataframe_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %% [markdown]
# # Rolling Statistics

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window

combined_dataframe_rolling = combined_dataframe.rolling(21).std()
combined_dataframe_rolling.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Calculate Correlation

# %%
# Construct a correlation table
correlation = combined_dataframe.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# # Calculate Covariance

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)


daily_returns = combined_dataframe.pct_change()
daily_returns.dropna(inplace=True)

sp500_history_csv

daily_returns.sort_index()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04                  -2.762070           -1.650792
# 2015-03-05                   0.800968            0.257544
# 2015-03-06                  -2.968465           -1.876837
# 2015-03-09                  -1.073656           -2.182252
# 2015-03-10                 -18.625495           -2.263954
# ...                               ...                 ...
# 2019-04-16                  -2.898341           -1.335693
# 2019-04-17                  -2.073108          -17.661104
# 2019-04-18                  -1.499843           -1.188925
# 2019-04-22                  -2.785826           -7.001458
# 2019-04-23                  -3.771893           -1.475216
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-04                     4.113646               -1.641381  3.422374
# 2015-03-05                    -1.929234                0.596558 -0.888803
# ...

# %%
whale_returns_data
#cov = whale_returns_data["SOROS FUND MANAGEMENT LLC"].cov()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
cov = combined_dataframe["BERKSHIRE HATHAWAY INC"].rolling(60).cov(combined_dataframe["S&P 500"])
cov
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000055
# 2019-04-17    0.000049
# 2019-04-18    0.000049
# 2019-04-22    0.000049
# 2019-04-23    0.000048
# Length: 1043, dtype: float64

# %%
variance = combined_dataframe["S&P 500"].rolling(60).var()
variance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000041
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# 2019-04-23    0.000037
# Name: S&P 500, Length: 1043, dtype: float64

# %%
beta= cov/variance
beta
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    1.337986
# 2019-04-17    1.301791
# 2019-04-18    1.302226
# 2019-04-22    1.304125
# 2019-04-23    1.278284
# Length: 1043, dtype: float64

# %%
beta.plot(figsize=(20,10));

# %%
combined_dataframe.ewm(halflife=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Sharpe Ratios

# %%
# Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# Calculate annualized Sharpe Ratios
sharpe_ratios = (combined_dataframe.mean() * 252) / (combined_dataframe.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
#On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:
# Yes, Algo 1 especially outperforms the "whales" and the "market"

# %% [markdown]
# # Portfolio Returns

# %%
# 1) Google Finance CSV for Google read in and .sort_index

file_path = Path("Instructions/Starter_Code/Resources/goog_historical.csv")
google_csv = pd.read_csv(file_path, infer_datetime_format=True, parse_dates=True, index_col="Trade DATE").sort_index()

google_csv.dropna().head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
#plot google finance csv
#google_csv.plot(figsize=(20,10))
google_csv.dropna()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59
# ...           ...      ...
# 2019-05-03   GOOG  1185.40
# 2019-05-06   GOOG  1189.39
# 2019-05-07   GOOG  1174.10
# 2019-05-08   GOOG  1166.27
# 2019-05-09   GOOG  1162.38
#
# [250 rows x 2 columns]

# %%
# 2) Aapl read in with datetime and .sort_index()
file_path = Path("Instructions/Starter_Code/Resources/aapl_historical.csv")
aapl_csv = pd.read_csv(file_path, infer_datetime_format=True, parse_dates=True, index_col="Trade DATE").sort_index()
aapl_csv.dropna()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99
# ...           ...     ...
# 2019-05-03   AAPL  211.75
# 2019-05-06   AAPL  208.48
# 2019-05-07   AAPL  202.86
# 2019-05-08   AAPL  202.90
# 2019-05-09   AAPL  200.72
#
# [250 rows x 2 columns]

# %%
# 3)Costco read in csv and datetime and sort
file_path = Path("Instructions/Starter_Code/Resources/cost_historical.csv")
cost_csv = pd.read_csv(file_path, infer_datetime_format=True, parse_dates=True, index_col="Trade DATE").sort_index()

cost_csv.dropna()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60
# ...           ...     ...
# 2019-05-03   COST  244.62
# 2019-05-06   COST  244.23
# 2019-05-07   COST  240.18
# 2019-05-08   COST  241.34
# 2019-05-09   COST  243.47
#
# [250 rows x 2 columns]

# %% [markdown]
# ## Concat Dataframe

# %%
#Concat and .pct_change() for daily returns

combined_googfinance_data = pd.concat([google_csv, aapl_csv, cost_csv], axis=0, join = "inner")

combined_googfinance_data.tail()

# combined_dataframe_pctchange = combined_dataframe.dropna().pct_change()
# combined_dataframe_pctchange.dropna()
combined_googfinance_data.reset_index()
combined_googfinance_data = combined_googfinance_data.pivot_table(index='Trade DATE', columns='Symbol', values='NOCP')
combined_googfinance_data = combined_googfinance_data.pct_change()
combined_googfinance_data.dropna()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339
# ...              ...       ...       ...
# 2019-05-03  0.012431  0.007953  0.019602
# 2019-05-06 -0.015443 -0.001594  0.003366
# 2019-05-07 -0.026957 -0.016583 -0.012855
# 2019-05-08  0.000197  0.004830 -0.006669
# 2019-05-09 -0.010744  0.008826 -0.003335
#
# [249 rows x 3 columns]

# %%
weights = [1/3, 1/3, 1/3]

combined_googfinance_weights = combined_googfinance_data.dot(weights)

combined_googfinance_weights


# combined_googfinance_data.plot(figsize=(20, 10))


# combined_dataframe.pivot(index='Date', columns='symbol', values='close')
# Out:
# Trade DATE
# 2018-05-11         NaN
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
#                 ...
# 2019-05-03    0.013329
# 2019-05-06   -0.004557
# 2019-05-07   -0.018798
# 2019-05-08   -0.000547
# 2019-05-09   -0.001751
# Length: 250, dtype: float64

# %% [markdown]
# # Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns #and drop NaN
combined_dataframe['Goog Finance'] = combined_googfinance_weights
combined_dataframe.dropna().tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500  Goog Finance
# Date
# 2019-04-16  0.002899  0.000509      0.000340
# 2019-04-17 -0.005228 -0.002274      0.009292
# ...

# %%
# Box Plot Concat data
combined_dataframe.plot.box(figsize = (20,10)
                        )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
#  Risk
# Determine the risk of each portfolio:
# Create a box plot for each portfolio. 
# Calculate the standard deviation for all portfolios
# Determine which portfolios are riskier than the S&P 500
# Calculate the Annualized Standard Deviation

#Daily Returns
# Daily Standard Deviation

# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE

#Daily Returns -
combined_dataframe.dropna()
combined_dataframe.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Box Plot Each Portfolio #Algo
algo_returns_csv.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# Box Plot Portfolio #Whale
whale_returns_data.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#Box Plot #Google Finance
combined_googfinance_data.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#Box Plot S&P
sp500_percent_change.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#Standard Deviation of combined data frame
combined_data_standard_deviation = combined_data_standard_deviation.sort_values()
combined_data_standard_deviation
# Out:
# PAULSON & CO.INC.              0.007353
# Algo 1                         0.008423
# Algo 2                         0.008791
# SOROS FUND MANAGEMENT LLC      0.009240
# S&P 500                        0.009578
# Goog Finance                   0.013323
# TIGER GLOBAL MANAGEMENT LLC    0.014648
# BERKSHIRE HATHAWAY INC         0.015569
# dtype: float64

# %%
#Calculate annualized standard dev (252 Trading Days)

combined_annualized_std = combined_data_standard_deviation * np.sqrt(252)
combined_annualized_std.plot.box()
# Out:
# <AxesSubplot:>

# %%
whale_returns_data = np.random.normal(scale=.5, size=10000)
algo_returns_std = np.random.normal(scale=1.0, size=10000)
combined_googfinance_data = np.random.normal(scale=1.5, size=10000)

portfolio_std = pd.DataFrame({
    "0.5": whale_returns_std,
    "1.0": algo_returns_std,
    "1.5": combined_googfinance_data
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-329-eb6077266736> in <module>
#       3 combined_googfinance_data = np.random.normal(scale=1.5, size=10000)
#       4
# ----> 5 portfolio_std = pd.DataFrame({
#       6     "0.5": whale_returns_std,
#       7     "1.0": algo_returns_std,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...

# %%
# Plot cumulative returns
#cumulative_returns 
# Plot cumulative returns
#cumulative_returns 
# combined_annualized_std = (1 + combined_dataframe).cumprod() - 1
# combined

combined_googfinance_data.ewm(halflife=21).std().plot(figsize=(20,10))

# %%
# Portfolio Analysis comparing std 
combined_dataframe.ewm(halflife=21).std().plot(figsize=(20,10))

# %%
# Out:
# PAULSON & CO.INC.              0.007353
# Algo 1                         0.008423
# Algo 2                         0.008791
# SOROS FUND MANAGEMENT LLC      0.009240
# S&P 500                        0.009578
# Goog Finance                   0.013323
# TIGER GLOBAL MANAGEMENT LLC    0.014648
# BERKSHIRE HATHAWAY INC         0.015569
# dtype: float64

# %% [markdown]
# # Sharpe Ratios

# %%
sharpe_ratios = (combined_data_standard_deviation.mean()*252)/(combined_data_standard_deviation* np.sqrt(252))
sharpe_ratios
# Out:
# PAULSON & CO.INC.              23.456821
# Algo 1                         20.479288
# Algo 2                         19.620451
# SOROS FUND MANAGEMENT LLC      18.668173
# S&P 500                        18.007813
# Goog Finance                   12.946651
# TIGER GLOBAL MANAGEMENT LLC    11.775456
# BERKSHIRE HATHAWAY INC         11.078731
# dtype: float64

# %%
#Plot Sharpe Ratio # Note for instructor - I know I must have done this wrong but for the sake of completion since it is already late I could not figure out what exactly I am doing wrong.
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>
